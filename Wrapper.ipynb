# %% [markdown]
# <a href="https://colab.research.google.com/github/Indradumnabanerji/FunctionalRecommenderSystems/blob/main/LTOCF.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from zipfile import ZipFile
file_name = 'LT-OCF-main.zip'

with ZipFile(file_name, 'r') as zip:
  zip.extractall()
  print('Done')
# Out:
# Done

# %%
#Path and version numbers for python
# !which python
# !python --version
# Out:
# /usr/local/bin/python
# Python 3.7.13

# %%
# %env PYTHONPATH=
# Out:
# env: PYTHONPATH=

# %%
# %%bash
# MINICONDA_INSTALLER_SCRIPT=Miniconda3-py37_4.12.0-Linux-x86_64.sh
# MINICONDA_PREFIX=/usr/local
# wget https://repo.continuum.io/miniconda/$MINICONDA_INSTALLER_SCRIPT
# chmod +x $MINICONDA_INSTALLER_SCRIPT
# ./$MINICONDA_INSTALLER_SCRIPT -b -f -p $MINICONDA_PREFIX
# Out:
# PREFIX=/usr/local
# Unpacking payload ...
# ...
# Solving environment: ...working... done
#
# # All requested packages already installed.
#
# installation finished.
# --2022-08-27 10:35:09--  https://repo.continuum.io/miniconda/Miniconda3-py37_4.12.0-Linux-x86_64.sh
# Resolving repo.continuum.io (repo.continuum.io)... 104.18.200.79, 104.18.201.79, 2606:4700::6812:c94f, ...
# Connecting to repo.continuum.io (repo.continuum.io)|104.18.200.79|:443... connected.
# HTTP request sent, awaiting response... 301 Moved Permanently
# Location: https://repo.anaconda.com/miniconda/Miniconda3-py37_4.12.0-Linux-x86_64.sh [following]
# --2022-08-27 10:35:09--  https://repo.anaconda.com/miniconda/Miniconda3-py37_4.12.0-Linux-x86_64.sh
# Resolving repo.anaconda.com (repo.anaconda.com)... 104.16.131.3, 104.16.130.3, 2606:4700::6810:8303, ...
# Connecting to repo.anaconda.com (repo.anaconda.com)|104.16.131.3|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# ...

# %%
# !which conda # should return /usr/local/bin/conda
# !conda --version # should return 4.5.4
# !which python # still returns /usr/local/bin/python
# !python --version # now returns Python 3.6.5 :: Anaconda, Inc.
# !conda update --channel defaults --all --yes
# Out:
# /usr/local/bin/conda
# conda 4.12.0
# /usr/local/bin/python
# Python 3.7.13
# done
# done
#
# ## Package Plan ##
#
#   environment location: /usr/local
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     _openmp_mutex-5.1          |            1_gnu          21 KB
#     ca-certificates-2022.07.19 |       h06a4308_0         124 KB
#     certifi-2022.6.15          |   py37h06a4308_0         153 KB
#     cffi-1.15.1                |   py37h74dc2b5_0         227 KB
#     conda-4.14.0               |   py37h06a4308_0         909 KB
#     cryptography-37.0.1        |   py37h9ce1e76_0         1.3 MB
#     cytoolz-0.11.0             |   py37h7b6447c_0         328 KB
#     ld_impl_linux-64-2.38      |       h1181459_1         654 KB
#     libgcc-ng-11.2.0           |       h1234567_1         5.3 MB
#     libgomp-11.2.0             |       h1234567_1         474 KB
# ...

# %%
# %cd LT-OCF-main
# !conda env create -f environment.yml  
# !conda activate lt-ocf
# Out:
# /content/LT-OCF-main
# done
# done
#
# ...
# mkl_fft-1.3.0        | 167 KB    | : 100% 1.0/1 [00:00<00:00,  9.46it/s]
# scipy-1.5.2          | 14.3 MB   | : 100% 1.0/1 [00:00<00:00,  1.88it/s]
# threadpoolctl-2.2.0  | 16 KB     | : 100% 1.0/1 [00:00<00:00, 16.31it/s]
# python-dateutil-2.8. | 233 KB    | : 100% 1.0/1 [00:00<00:00, 17.80it/s]
# pip-20.3.3           | 1.8 MB    | : 100% 1.0/1 [00:00<00:00,  6.04it/s]
# numpy-1.19.2         | 22 KB     | : 100% 1.0/1 [00:00<00:00, 19.59it/s]
# mkl_random-1.1.1     | 322 KB    | : 100% 1.0/1 [00:00<00:00, 18.10it/s]
# libgfortran4-7.5.0   | 995 KB    | : 100% 1.0/1 [00:00<00:00, 12.74it/s]
# joblib-1.1.0         | 211 KB    | : 100% 1.0/1 [00:00<00:00, 14.45it/s]
# pandas-1.2.0         | 8.5 MB    | : 100% 1.0/1 [00:01<00:00,  1.00s/it]
# numpy-base-1.19.2    | 4.1 MB    | : 100% 1.0/1 [00:00<00:00,  4.59it/s]
# python-3.7.9         | 45.3 MB   | : 100% 1.0/1 [00:01<00:00,  1.01s/it]
# ...

# %%
# !conda install -c pytorch pytorch=1.7.1
# Out:
# done
# failed with initial frozen solve. Retrying with flexible solve.
# failed with repodata from current_repodata.json, will retry with next repodata source.
# done
# done
#
# ## Package Plan ##
#
#   environment location: /usr/local
#
#   added / updated specs:
#     - pytorch=1.7.1
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     cudatoolkit-11.0.221       |       h6bb024c_0       622.9 MB
#     intel-openmp-2021.4.0      |    h06a4308_3561         4.2 MB
#     libuv-1.40.0               |       h7b6447c_0         736 KB
#     mkl-2021.4.0               |     h06a4308_640       142.6 MB
#     mkl-service-2.4.0          |   py37h7f8727e_0          56 KB
#     mkl_fft-1.3.1              |   py37hd3c417c_0         172 KB
#     mkl_random-1.2.2           |   py37h51133e4_0         287 KB
#     ninja-1.10.2               |       h06a4308_5           8 KB
# ...

# %%
# !conda install -c pandas pandas=1.3.4
# !conda install -c anaconda scipy
# Out:
# done
# failed with initial frozen solve. Retrying with flexible solve.
# done
# done
#
# ## Package Plan ##
#
#   environment location: /usr/local
#
#   added / updated specs:
#     - pandas=1.3.4
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     bottleneck-1.3.5           |   py37h7deecbd_0         115 KB
#     numexpr-2.8.3              |   py37h807cd23_0         124 KB
#     packaging-21.3             |     pyhd3eb1b0_0          36 KB
#     pandas-1.3.4               |   py37h8c16a72_0         9.2 MB
#     pyparsing-3.0.9            |   py37h06a4308_0         150 KB
#     ------------------------------------------------------------
#                                            Total:         9.6 MB
#
# The following NEW packages will be INSTALLED:
#
#   bottleneck         pkgs/main/linux-64::bottleneck-1.3.5-py37h7deecbd_0
# ...

# %%
# !conda install -c conda-forge torchdiffeq
# Out:
# done
# \
# ...
#   - anaconda/linux-64::openssl-1.1.1q-h7f8727e_0
# done
#
# ## Package Plan ##
#
#   environment location: /usr/local
#
#   added / updated specs:
#     - torchdiffeq
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     ca-certificates-2022.6.15  |       ha878542_0         149 KB  conda-forge
#     certifi-2022.6.15          |     pyhd8ed1ab_1         154 KB  conda-forge
#     conda-4.14.0               |   py37h89c1867_0        1010 KB  conda-forge
#     python_abi-3.7             |          2_cp37m           4 KB  conda-forge
#     torchdiffeq-0.2.2          |     pyhd8ed1ab_0          28 KB  conda-forge
#     ------------------------------------------------------------
#                                            Total:         1.3 MB
#
# The following NEW packages will be INSTALLED:
#
#   python_abi         conda-forge/linux-64::python_abi-3.7-2_cp37m
# ...

# %%
# !conda install -c anaconda scikit-learn
# Out:
# done
# done
#
# ## Package Plan ##
#
#   environment location: /usr/local
#
#   added / updated specs:
#     - scikit-learn
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     joblib-1.1.0               |     pyhd3eb1b0_0         211 KB  anaconda
#     scikit-learn-1.0.2         |   py37h51133e4_1         7.4 MB  anaconda
#     threadpoolctl-2.2.0        |     pyh0d69192_0          16 KB  anaconda
#     ------------------------------------------------------------
#                                            Total:         7.7 MB
#
# The following NEW packages will be INSTALLED:
#
#   joblib             anaconda/noarch::joblib-1.1.0-pyhd3eb1b0_0
#   scikit-learn       anaconda/linux-64::scikit-learn-1.0.2-py37h51133e4_1
#   threadpoolctl      anaconda/noarch::threadpoolctl-2.2.0-pyh0d69192_0
#
# The following packages will be UPDATED:
#
# ...

# %%
# !conda install -c conda-forge tensorboardx
# Out:
# done
# /
# ...
#   - anaconda/linux-64::openssl-1.1.1q-h7f8727e_0
# done
#
# ## Package Plan ##
#
#   environment location: /usr/local
#
#   added / updated specs:
#     - tensorboardx
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     libprotobuf-3.15.8         |       h780b84a_1         2.5 MB  conda-forge
#     protobuf-3.15.8            |   py37hcd2ae1e_0         334 KB  conda-forge
#     tensorboardx-2.5.1         |     pyhd8ed1ab_0          84 KB  conda-forge
#     ------------------------------------------------------------
#                                            Total:         2.9 MB
#
# The following NEW packages will be INSTALLED:
#
#   libprotobuf        conda-forge/linux-64::libprotobuf-3.15.8-h780b84a_1
#   protobuf           conda-forge/linux-64::protobuf-3.15.8-py37hcd2ae1e_0
#   tensorboardx       conda-forge/noarch::tensorboardx-2.5.1-pyhd8ed1ab_0
#
# ...

# %%
# !sh ltocf_gowalla_rk4.sh
# Out:
#  ██████╗████████╗    ██████╗  ██████╗███████╗
# ██╔════╝╚══██╔══╝   ██╔═══██╗██╔════╝██╔════╝
# ██║        ██║█████╗██║   ██║██║     █████╗
# ██║        ██║╚════╝██║   ██║██║     ██╔══╝
# ╚██████╗   ██║      ╚██████╔╝╚██████╗██║
#  ╚═════╝   ╚═╝       ╚═════╝  ╚═════╝╚═╝
#
#
# Current cuda device  0
# Cpp extension not loaded
# >>SEED: 2020
# loading [../data/gowalla]
# 810128 interactions for training
# 217242 interactions for testing
# gowalla Sparsity : 0.0008396216228570436
# gowalla is ready to go
# ===========config================
# {'A_n_fold': 100,
#  'A_split': False,
#  'K': 4.0,
#  'bigdata': False,
#  'bpr_batch_size': 2048,
#  'decay': 0.0001,
#  'dropout': 0,
#  'dual_res': False,
#  'keep_prob': 0.6,
#  'latent_dim_rec': 64,
#  'learnable_time': True,
#  'lightGCN_n_layers': 3,
#  'lr': 0.0001,
#  'lr_time': 1e-06,
#  'multicore': 0,
#  'pretrain': 1,
#  'pretrained_file_name': 'gowalla-rk4.pth.tar',
#  'solver': 'rk4',
#  'test_u_batch_size': 100,
# ...

# %%
# !sh ltocf_gowalla_rk4_fixed.sh
# Out:
#  ██████╗████████╗    ██████╗  ██████╗███████╗
# ██╔════╝╚══██╔══╝   ██╔═══██╗██╔════╝██╔════╝
# ██║        ██║█████╗██║   ██║██║     █████╗
# ██║        ██║╚════╝██║   ██║██║     ██╔══╝
# ╚██████╗   ██║      ╚██████╔╝╚██████╗██║
#  ╚═════╝   ╚═╝       ╚═════╝  ╚═════╝╚═╝
#
#
# Current cuda device  0
# Cpp extension not loaded
# >>SEED: 2020
# loading [../data/gowalla]
# 810128 interactions for training
# 217242 interactions for testing
# gowalla Sparsity : 0.0008396216228570436
# gowalla is ready to go
# ===========config================
# {'A_n_fold': 100,
#  'A_split': False,
#  'K': 4.0,
#  'bigdata': False,
#  'bpr_batch_size': 2048,
#  'decay': 0.0001,
#  'dropout': 0,
#  'dual_res': False,
#  'keep_prob': 0.6,
#  'latent_dim_rec': 64,
#  'learnable_time': False,
#  'lightGCN_n_layers': 3,
#  'lr': 0.001,
#  'lr_time': 0.0001,
#  'multicore': 0,
#  'pretrain': 0,
#  'pretrained_file_name': 'ltocf',
#  'solver': 'rk4',
#  'test_u_batch_size': 100,
#  'time_split': 4}
# ...
